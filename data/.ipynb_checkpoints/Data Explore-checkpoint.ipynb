# %%
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
import re
import string
import json
import pickle
from collections import defaultdict

# %matplotlib inline

pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

from bs4 import BeautifulSoup
# The "requests" library makes working with HTTP requests easier
# than the built-in urllib libraries.
import requests
from urllib2 import urlopen

# %%
data=pd.read_csv("../data/anime_info.csv",sep='\t', index_col=0)

# %%
data.shape
# Out:
# (7281, 11)

# %%
data[1:100]
# Out:
#                                                                                               altname                              atype                                         categories         date  date_pub                                        description                                               name                       rank                             rating                                            related                studio
# +A-Channel                                                                                        NaN    \nDVD Special (11 eps x 2 min)           [Comedy, Slice of Life, Based on a Manga]          NaN      2011  There are many untold stories in the lives of ...                                         +A-Channel  \n       Rank #2,398             3.334 of 5 from 1,192 votes                     [A-Channel, A-Channel + smile]         Studio Gokumi
# .hack//G.U. Returner                                                                              NaN                      \nOVA (1 ep)                      [MMORPG, RPG, Virtual Reality]          NaN      2007  "There is something I wish to entrust to you; ...                               .hack//G.U. Returner  \n       Rank #2,504             3.291 of 5 from 2,021 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...                   NaN
# .hack//G.U. Trilogy                                                                               NaN           \nMovie (1 ep x 93 min)        [CG Animation, MMORPG, RPG, Virtual Reality]          NaN      2008  The World is an ordinary online game – or at l...                                .hack//G.U. Trilogy  \n       Rank #1,576             3.671 of 5 from 2,814 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...                   NaN
# .hack//G.U. Trilogy Parody                                                                        NaN      \nDVD Special (1 ep x 6 min)              [Comedy, MMORPG, RPG, Virtual Reality]          NaN      2008                                                NaN                         .hack//G.U. Trilogy Parody  \n       Rank #3,993               2.691 of 5 from 714 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...                   NaN
# .hack//GIFT                                                                                       NaN                      \nOVA (1 ep)               [Chibi, MMORPG, RPG, Virtual Reality]          NaN      2003  As thanks for playing in The World, its makers...                                        .hack//GIFT  \n       Rank #4,108             2.646 of 5 from 2,721 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...             BEE TRAIN
# .hack//LIMINALITY                                                                                 NaN                     \nOVA (4 eps)                                                 NaN          NaN      2002  While characters within the MMORPG entitled "T...                                  .hack//LIMINALITY  \n       Rank #3,073             3.064 of 5 from 4,253 votes  [.hack//SIGN, .hack//Legend Of The Twilight, ....             BEE TRAIN
# .hack//Legend Of The Twilight                                                                     NaN                     \nTV (12 eps)              [Sci Fi, MMORPG, RPG, Virtual Reality]          NaN      2003  Shuugo and Rena think they're just two sibling...                      .hack//Legend Of The Twilight  \n       Rank #3,039             3.078 of 5 from 7,252 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//SIGN -...             BEE TRAIN
# .hack//Quantum                                                                                    NaN                     \nOVA (3 eps)                   [Action, Mystery, Sci Fi, MMORPG]          NaN      2010  Asumi Aida is a cheerful high school student w...                                     .hack//Quantum    \n       Rank #974             3.933 of 5 from 2,328 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...         Kinema Citrus
# .hack//Quantum Specials                                                                           NaN     \nDVD Special (3 eps x 3 min)                                                 NaN          NaN      2011                                                NaN                            .hack//Quantum Specials  \n       Rank #3,441               2.916 of 5 from 311 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...         Kinema Citrus
# .hack//Roots                                                                                      NaN            \nTV (26 eps x 24 min)                      [MMORPG, RPG, Virtual Reality]  Spring 2006      2006  Years after the fantasy MMORPG known as 'The W...                                       .hack//Roots  \n       Rank #2,198             3.414 of 5 from 6,266 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...             BEE TRAIN
# .hack//SIGN                                                                                       NaN                     \nTV (26 eps)   [Adventure, Fantasy, Sci Fi, Hacking, MMORPG, ...          NaN      2002  In a massive online world, people act only as ...                                        .hack//SIGN  \n       Rank #2,224            3.404 of 5 from 15,916 votes  [.hack//LIMINALITY, .hack//Legend Of The Twili...             BEE TRAIN
# .hack//SIGN - Intermezzo                                                                          NaN                      \nOVA (1 ep)                      [MMORPG, RPG, Virtual Reality]          NaN      2003  Bear and Mimiru are on the trail of a time-res...                           .hack//SIGN - Intermezzo  \n       Rank #2,639             3.236 of 5 from 3,399 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...             BEE TRAIN
# .hack//SIGN - Unison                                                                              NaN                      \nOVA (1 ep)                      [MMORPG, RPG, Virtual Reality]          NaN      2003  The World is safe from viruses and harm. Kite,...                               .hack//SIGN - Unison  \n       Rank #2,527             3.281 of 5 from 3,326 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...             BEE TRAI
# Accel World                                                                                       NaN                     \nTV (24 eps)   [Action, Sci Fi, Based on a Light Novel, Virtu...  Spring 2012      2012  In a world where everyone connects to an onlin...                                        Accel World    \n       Rank #859            3.991 of 5 from 16,979 votes  [Accel World: Infinite Burst, Accel World OVA,...               Sunrise
# Accel World OVA                                                                                   NaN                     \nOVA (2 eps)   [Action, Sci Fi, Based on a Light Novel, Virtu...          NaN      2012  The Black Legion members are enjoying a rare o...                                    Accel World OVA  \n       Rank #1,753             3.595 of 5 from 4,440 votes  [Accel World: Infinite Burst, Accel World, Acc...               Sunrise
# Accel World Specials                                                                              NaN     \nDVD Special (8 eps x 4 min)             [Comedy, Based on a Light Novel, Chibi]          NaN      2012                                                NaN                               Accel World Specials  \n       Rank #4,381             2.535 of 5 from 2,330 votes  [Accel World: Infinite Burst, Accel World, Acc...             J.C.Staff
#
# [99 rows x 11 columns]

# %%
# select vote and numerical ratings within "rating"
votes=[]
ratings=[]
for row in data.index:
    l=data.ix[row,"rating"].split(" ")
    temp=(l[4]).replace(",","")
    if (temp=="an"):
        temp=0
    votes.append(int(temp))
    ratings.append(float(l[0].replace(",","")))

# %%
# append new columns of votes and ratings for each anime
data["votes"]=votes
data["ratings"]=ratings

# %%
# remove rating
data.drop("rating", axis=1)
# Out:
#                                                                                               altname                              atype                                         categories         date  date_pub                                        description                                               name                       rank                                            related                studio  votes  ratings
# (Making of) Evangelion: Another Impact                                                            NaN   \n        Web (1 ep x 6 min)      [Sci Fi, CG Animation, Japan Animator's Exhibi...          NaN      2015  This episode is a making film of #12 "evangeli...             (Making of) Evangelion: Another Impact  \n       Rank #5,996       [Neon Genesis Evangelion, Neon Genesis Evangel...          Studio Khara    153    1.743
# +A-Channel                                                                                        NaN    \nDVD Special (11 eps x 2 min)           [Comedy, Slice of Life, Based on a Manga]          NaN      2011  There are many untold stories in the lives of ...                                         +A-Channel  \n       Rank #2,398                          [A-Channel, A-Channel + smile]         Studio Gokumi   1192    3.334
# .hack//G.U. Returner                                                                              NaN                      \nOVA (1 ep)                      [MMORPG, RPG, Virtual Reality]          NaN      2007  "There is something I wish to entrust to you; ...                               .hack//G.U. Returner  \n       Rank #2,504       [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...                   NaN   2021    3.291
# .hack//G.U. Trilogy                                                                               NaN           \nMovie (1 ep x 93 min)        [CG Animation, MMORPG, RPG, Virtual Reality]          NaN      2008  The World is an ordinary online game – or at l...                                .hack//G.U. Trilogy  \n       Rank #1,576       [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...                   NaN   2814    3.671
# .hack//G.U. Trilogy Parody                                                                        NaN      \nDVD Special (1 ep x 6 min)              [Comedy, MMORPG, RPG, Virtual Reality]          NaN      2008                                                NaN                         .hack//G.U. Trilogy Parody  \n       Rank #3,993       [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...                   NaN    714    2.691
# .hack//GIFT                                                                                       NaN                      \nOVA (1 ep)               [Chibi, MMORPG, RPG, Virtual Reality]          NaN      2003  As thanks for playing in The World, its makers...                                        .hack//GIFT  \n       Rank #4,108       [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...             BEE TRAIN   2721    2.646
# .hack//LIMINALITY                                                                                 NaN                     \nOVA (4 eps)                                                 NaN          NaN      2002  While characters within the MMORPG entitled "T...                                  .hack//LIMINALITY  \n       Rank #3,073       [.hack//SIGN, .hack//Legend Of The Twilight, ....             BEE TRAIN   4253    3.064
# .hack//Legend Of The Twilight                                                                     NaN                     \nTV (12 eps)              [Sci Fi, MMORPG, RPG, Virtual Reality]          NaN      2003  Shuugo and Rena think they're just two sibling...                      .hack//Legend Of The Twilight  \n       Rank #3,039       [.hack//SIGN, .hack//LIMINALITY, .hack//SIGN -...             BEE TRAIN   7252    3.078
# .hack//Quantum                                                                                    NaN                     \nOVA (3 eps)                   [Action, Mystery, Sci Fi, MMORPG]          NaN      2010  Asumi Aida is a cheerful high school student w...                                     .hack//Quantum    \n       Rank #974       [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...         Kinema Citr
\nMusic Video (1 ep x 4 min)                                                 NaN          NaN      2013                                                NaN                                  siinamota: MOSAIC  \n       Rank #6,354                                                     NaN                   NaN     16    1.493
# siinamota: Pikkooon!!                                                           Alt title: Pikkooon!!      \nMusic Video (1 ep x 4 min)                                                 NaN          NaN      2013                                                NaN                              siinamota: Pikkooon!!  \n       Rank #6,445                                                     NaN                   NaN     14    1.393
# sola                                                                                              NaN                     \nTV (13 eps)         [Drama, Mystery, Romance, Based on a Manga]  Spring 2007      2007  Morimiya Yorito is a normal student who has an...                                               sola  \n       Rank #1,622                                         [sola Specials]                 Nomad   6595    3.651
# sola Specials                                                                                     NaN    \nDVD Special (2 eps x 24 min)                                                 NaN          NaN      2007                                                NaN                                      sola Specials  \n       Rank #2,799                                                  [sola]                 Nomad    773    3.173
# the pillows: 1989                                                                     Alt title: 1989      \nMusic Video (1 ep x 7 min)                                                 NaN          NaN      2009                                                NaN                                  the pillows: 1989  \n       Rank #5,709                                                     NaN                   NaN     19    1.913
# the pillows: Instant Music                                                   Alt title: Instant Music      \nMusic Video (1 ep x 3 min)                                                 NaN          NaN      1998                                                NaN                         the pillows: Instant Music  \n       Rank #6,241                                                     NaN                   NaN     10    1.581
# the pillows: Wake Up! Dodo                                                   Alt title: Wake Up! Dodo      \nMusic Video (1 ep x 4 min)                                                 NaN          NaN      2007                                                NaN                         the pillows: Wake Up! Dodo                         \n                                                NaN                   NaN      0    3.000
# until You come to me.                                                                             NaN   \n        Web (1 ep x 7 min)                  [Japan Animator's Exhibition, Shorts]          NaN      2014                                                NaN                              until You come to me.  \n       Rank #5,112       [Neon Genesis Evangelion, Neon Genesis Evangel...          Studio Khara    301    2.216
# wowaka: Antinotice                                                              Alt title: Antinotice      \nMusic Video (1 ep x 3 min)                                          [Vocaloid]          NaN      2011                                                NaN                                 wowaka: Antinotice  \n       Rank #4,835                                                     NaN                   NaN     97    2.342
# xxxHOLiC Kei                                                                                      NaN                     \nTV (13 eps)   [Comedy, Based on a Manga, Episodic, Japanese ...          NaN      2008  Watanuki, who is able to see the spirit world,...                                       xxxHOLiC Kei    \n       Rank #154       [XXXHOLiC the Movie: A Midsummer Night's Dream...        Production I.G   6463    4.400
# xxxHOLiC Rou                                                                                      NaN            \nOVA (2 eps x 40 min)           [Drama, Japanese Mythology, Supernatural]          NaN      2010  It’s been ten years since Yuuko disappeared fr...                                       xxxHOLiC Rou    \n       Rank #158       [XXXHOLiC the Movie: A Midsummer Night's Dream...        Production I.G   3039    4.397
# xxxHOLiC Shunmuki                                                                                 NaN                     \nOVA (2 eps)                              [Comedy, Supernatural]          NaN      2009  Following his near-fatal accident, Watanuki is...                                  xxxHOLiC Shunmuki    \n       Rank #270       [XXXHOLiC the Movie: A Midsummer Night's Dream...        Production I.G   3827    4.322
#
# [7281 rows x 12 columns]

# %%
# Ratings distribution
x=np.arange(10)
plt.hist(data["ratings"])
plt.show()

# %%
# pick out numerical rank, rank= -1 if rank=NULL
ranks=[]
for row in data.index:
    l=data.ix[row,"rank"].split("#",1)
    if (len(l)>1):
        ranks.append(int(l[1].replace(",","")))
    else:
        ranks.append(-1)

# %%
# drop rank column
# add new rank column with numerical values only
# data.drop("rank", axis=1)
data["rank"]=ranks

# %%
data.head(5)
# Out:
#                                        altname                             atype                                         categories date  date_pub                                        description                                    name  rank                       rating                                            related         studio  votes  ratings
# (Making of) Evangelion: Another Impact     NaN  \n        Web (1 ep x 6 min)      [Sci Fi, CG Animation, Japan Animator's Exhibi...  NaN      2015  This episode is a making film of #12 "evangeli...  (Making of) Evangelion: Another Impact  5996    1.743 of 5 from 153 votes  [Neon Genesis Evangelion, Neon Genesis Evangel...   Studio Khara    153    1.743
# +A-Channel                                 NaN   \nDVD Special (11 eps x 2 min)           [Comedy, Slice of Life, Based on a Manga]  NaN      2011  There are many untold stories in the lives of ...                              +A-Channel  2398  3.334 of 5 from 1,192 votes                     [A-Channel, A-Channel + smile]  Studio Gokumi   1192    3.334
# .hack//G.U. Returner                       NaN                     \nOVA (1 ep)                      [MMORPG, RPG, Virtual Reality]  NaN      2007  "There is something I wish to entrust to you; ...                    .hack//G.U. Returner  2504  3.291 of 5 from 2,021 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN   2021    3.291
# .hack//G.U. Trilogy                        NaN          \nMovie (1 ep x 93 min)        [CG Animation, MMORPG, RPG, Virtual Reality]  NaN      2008  The World is an ordinary online game – or at l...                     .hack//G.U. Trilogy  1576  3.671 of 5 from 2,814 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN   2814    3.671
# .hack//G.U. Trilogy Parody                 NaN     \nDVD Special (1 ep x 6 min)              [Comedy, MMORPG, RPG, Virtual Reality]  NaN      2008                                                NaN              .hack//G.U. Trilogy Parody  3993    2.691 of 5 from 714 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN    714    2.691

# %%
# pick out number of episodes for each movie, episodes=0 if doesn't exist
episodes=[]
for row in data.index:
    l=data.ix[row,"atype"].split("(",1)
    if (len(l)>1):
        n=l[1:]
        m=n[0].split(" ")
        episodes.append(int(m[0].replace("+","")))
    else:
        episodes.append(0)

# %%
# Amend episodes column into dataframe
data["eps"]=episodes
data.head(5)
# Out:
#                                        altname                             atype                                         categories date  date_pub                                        description                                    name  rank                       rating                                            related         studio  votes  ratings  eps
# (Making of) Evangelion: Another Impact     NaN  \n        Web (1 ep x 6 min)      [Sci Fi, CG Animation, Japan Animator's Exhibi...  NaN      2015  This episode is a making film of #12 "evangeli...  (Making of) Evangelion: Another Impact  5996    1.743 of 5 from 153 votes  [Neon Genesis Evangelion, Neon Genesis Evangel...   Studio Khara    153    1.743    1
# +A-Channel                                 NaN   \nDVD Special (11 eps x 2 min)           [Comedy, Slice of Life, Based on a Manga]  NaN      2011  There are many untold stories in the lives of ...                              +A-Channel  2398  3.334 of 5 from 1,192 votes                     [A-Channel, A-Channel + smile]  Studio Gokumi   1192    3.334   11
# .hack//G.U. Returner                       NaN                     \nOVA (1 ep)                      [MMORPG, RPG, Virtual Reality]  NaN      2007  "There is something I wish to entrust to you; ...                    .hack//G.U. Returner  2504  3.291 of 5 from 2,021 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN   2021    3.291    1
# .hack//G.U. Trilogy                        NaN          \nMovie (1 ep x 93 min)        [CG Animation, MMORPG, RPG, Virtual Reality]  NaN      2008  The World is an ordinary online game – or at l...                     .hack//G.U. Trilogy  1576  3.671 of 5 from 2,814 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN   2814    3.671    1
# .hack//G.U. Trilogy Parody                 NaN     \nDVD Special (1 ep x 6 min)              [Comedy, MMORPG, RPG, Virtual Reality]  NaN      2008                                                NaN              .hack//G.U. Trilogy Parody  3993    2.691 of 5 from 714 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN    714    2.691    1

# %%
data.dtypes
# Out:
# altname         object
# atype           object
# categories      object
# date            object
# date_pub       float64
# description     object
# name            object
# rank             int64
# rating          object
# related         object
# studio          object
# votes            int64
# ratings        float64
# eps              int64
# dtype: object

# %%
# pick out minutes per episode, emin=0 if does not exist
emin=[]
for row in data.index:
    l=data.ix[row,"atype"].split("x",1)
    if (len(l)>1):
        n=l[1:]
        m=n[0].split(" ")
        emin.append(int(m[1]))
    else:
        emin.append(0)

# %%
# add emin (minutes per episode) into dataframe
data["emin"]=emin
data.head(5)
# Out:
#                                        altname                             atype                                         categories date  date_pub                                        description                                    name  rank                       rating                                            related         studio  votes  ratings  eps  emin
# (Making of) Evangelion: Another Impact     NaN  \n        Web (1 ep x 6 min)      [Sci Fi, CG Animation, Japan Animator's Exhibi...  NaN      2015  This episode is a making film of #12 "evangeli...  (Making of) Evangelion: Another Impact  5996    1.743 of 5 from 153 votes  [Neon Genesis Evangelion, Neon Genesis Evangel...   Studio Khara    153    1.743    1     6
# +A-Channel                                 NaN   \nDVD Special (11 eps x 2 min)           [Comedy, Slice of Life, Based on a Manga]  NaN      2011  There are many untold stories in the lives of ...                              +A-Channel  2398  3.334 of 5 from 1,192 votes                     [A-Channel, A-Channel + smile]  Studio Gokumi   1192    3.334   11     2
# .hack//G.U. Returner                       NaN                     \nOVA (1 ep)                      [MMORPG, RPG, Virtual Reality]  NaN      2007  "There is something I wish to entrust to you; ...                    .hack//G.U. Returner  2504  3.291 of 5 from 2,021 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN   2021    3.291    1     0
# .hack//G.U. Trilogy                        NaN          \nMovie (1 ep x 93 min)        [CG Animation, MMORPG, RPG, Virtual Reality]  NaN      2008  The World is an ordinary online game – or at l...                     .hack//G.U. Trilogy  1576  3.671 of 5 from 2,814 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN   2814    3.671    1    93
# .hack//G.U. Trilogy Parody                 NaN     \nDVD Special (1 ep x 6 min)              [Comedy, MMORPG, RPG, Virtual Reality]  NaN      2008                                                NaN              .hack//G.U. Trilogy Parody  3993    2.691 of 5 from 714 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN    714    2.691    1     6

# %%
t_length=[]
for i in range(0,len(emin)):
    t_length.append(int(emin[i])*int(episodes[i]))

# %%
len(t_length), data.shape
# Out:
# (7281, (7281, 15))

# %%
# adding total length of anime movies to column
data["tlength"]=t_length
data.head(5)
# Out:
#                                        altname                             atype                                         categories date  date_pub                                        description                                    name  rank                       rating                                            related         studio  votes  ratings  eps  emin  tlength
# (Making of) Evangelion: Another Impact     NaN  \n        Web (1 ep x 6 min)      [Sci Fi, CG Animation, Japan Animator's Exhibi...  NaN      2015  This episode is a making film of #12 "evangeli...  (Making of) Evangelion: Another Impact  5996    1.743 of 5 from 153 votes  [Neon Genesis Evangelion, Neon Genesis Evangel...   Studio Khara    153    1.743    1     6        6
# +A-Channel                                 NaN   \nDVD Special (11 eps x 2 min)           [Comedy, Slice of Life, Based on a Manga]  NaN      2011  There are many untold stories in the lives of ...                              +A-Channel  2398  3.334 of 5 from 1,192 votes                     [A-Channel, A-Channel + smile]  Studio Gokumi   1192    3.334   11     2       22
# .hack//G.U. Returner                       NaN                     \nOVA (1 ep)                      [MMORPG, RPG, Virtual Reality]  NaN      2007  "There is something I wish to entrust to you; ...                    .hack//G.U. Returner  2504  3.291 of 5 from 2,021 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN   2021    3.291    1     0        0
# .hack//G.U. Trilogy                        NaN          \nMovie (1 ep x 93 min)        [CG Animation, MMORPG, RPG, Virtual Reality]  NaN      2008  The World is an ordinary online game – or at l...                     .hack//G.U. Trilogy  1576  3.671 of 5 from 2,814 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN   2814    3.671    1    93       93
# .hack//G.U. Trilogy Parody                 NaN     \nDVD Special (1 ep x 6 min)              [Comedy, MMORPG, RPG, Virtual Reality]  NaN      2008                                                NaN              .hack//G.U. Trilogy Parody  3993    2.691 of 5 from 714 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN    714    2.691    1     6        6

# %%
# pick out type of anime
types=[]
for row in data.index:
    l=data.ix[row,"atype"].split("(",1)
    if (len(l)>1):
        types.append(l[0])
    else:
        types.append("NA")

# %%
data["type"]=types

# %%
# Frequency of Studios
a=pd.value_counts(data['studio'].values, sort=True)
subd=pd.DataFrame(a,a.index.values)
subd.columns=['Frequency']
subd.head(5)
# Out:
#                    Frequency
# Toei Animation           494
# Sunrise                  341
# MADHOUSE                 258
# J.C.Staff                245
# TMS Entertainment        209

# %%
# PLOT TOP 10 STUDIOS BY FREQUENCY
x=np.arange(10)
plt.bar(x,subd.ix[0:10,'Frequency'])
plt.xticks(x, a.index.values[0:10], rotation='vertical')
plt.show()

# %%
# some ratings said "6 needed to calculate average". Set ratings for these equal to -1
for row in data.index:
    l=data.ix[row,"ratings"]
    if l>5:
        l=-1
        data.ix[row,"ratings"]=l

# %%
# arrange studio by highest average ratings
studio_r=data.groupby("studio").aggregate(np.mean)["ratings"]
studio_r=studio_r.order(ascending=False)
subd_studio=pd.DataFrame(studio_r,a.index.values)
subd_studio.columns=['Average Ratings']
subd_studio = subd_studio.sort(['Average Ratings'], ascending=False)
subd_studio.head(5)
# Out:
#                           Average Ratings
# Automatic Flowers Studio            5.000
# IMAGIN                              4.388
# Studio Chizu                        4.384
# Studio Wombat                       4.355
# Purple Cow Studio Japan             4.196

# %%
# PLOT STUDIOS BY FREQUENCY AND AVERAGE RATINGS FOR COMPARISONS

fig, axes= plt.subplots(nrows=1, ncols=2, figsize=(12,8))
x=np.arange(10)
axes[0].bar(x,subd_studio.ix[0:10,'Average Ratings'])
axes[0].set_title('Average Ratings')
axes[0].set_xticks(x)
axes[0].set_xticklabels(a.index.values[0:10], rotation=90)
axes[0].set_xticks(x)
axes[0].set_xticklabels(a.index.values[0:10], rotation=90)
axes[1].bar(x,subd.ix[0:10,'Frequency'])
axes[1].set_title('Frequency')
axes[1].set_xticks(x)
axes[1].set_xticklabels(a.index.values[0:10], rotation=90)
# Out:
# [<matplotlib.text.Text at 0x1faaf390>,
#  <matplotlib.text.Text at 0x1fabae48>,
#  <matplotlib.text.Text at 0x1fbe6d30>,
#  <matplotlib.text.Text at 0x1fbf4400>,
#  <matplotlib.text.Text at 0x1fbf4a90>,
#  <matplotlib.text.Text at 0x1fbff160>,
#  <matplotlib.text.Text at 0x1fbff7f0>,
#  <matplotlib.text.Text at 0x1fbffe80>,
#  <matplotlib.text.Text at 0x1fc09550>,
#  <matplotlib.text.Text at 0x1fc09be0>]

# %%
data.head(5)
# Out:
#                                        altname                             atype                                         categories date  date_pub                                        description                                    name  rank                       rating                                            related         studio  votes  ratings  eps  emin  tlength            type
# (Making of) Evangelion: Another Impact     NaN  \n        Web (1 ep x 6 min)      [Sci Fi, CG Animation, Japan Animator's Exhibi...  NaN      2015  This episode is a making film of #12 "evangeli...  (Making of) Evangelion: Another Impact  5996    1.743 of 5 from 153 votes  [Neon Genesis Evangelion, Neon Genesis Evangel...   Studio Khara    153    1.743    1     6        6  \n        Web
# +A-Channel                                 NaN   \nDVD Special (11 eps x 2 min)           [Comedy, Slice of Life, Based on a Manga]  NaN      2011  There are many untold stories in the lives of ...                              +A-Channel  2398  3.334 of 5 from 1,192 votes                     [A-Channel, A-Channel + smile]  Studio Gokumi   1192    3.334   11     2       22  \nDVD Special
# .hack//G.U. Returner                       NaN                     \nOVA (1 ep)                      [MMORPG, RPG, Virtual Reality]  NaN      2007  "There is something I wish to entrust to you; ...                    .hack//G.U. Returner  2504  3.291 of 5 from 2,021 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN   2021    3.291    1     0        0          \nOVA
# .hack//G.U. Trilogy                        NaN          \nMovie (1 ep x 93 min)        [CG Animation, MMORPG, RPG, Virtual Reality]  NaN      2008  The World is an ordinary online game – or at l...                     .hack//G.U. Trilogy  1576  3.671 of 5 from 2,814 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN   2814    3.671    1    93       93        \nMovie
# .hack//G.U. Trilogy Parody                 NaN     \nDVD Special (1 ep x 6 min)              [Comedy, MMORPG, RPG, Virtual Reality]  NaN      2008                                                NaN              .hack//G.U. Trilogy Parody  3993    2.691 of 5 from 714 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN    714    2.691    1     6        6  \nDVD Special

# %%
# arrange studio by highest average ranks
studio_rank=data.groupby("studio").aggregate(np.mean)["rank"]
subd_studio_rank=pd.DataFrame(studio_rank,a.index.values)
subd_studio_rank.columns=['Average Rankings']
subd_studio_rank = subd_studio_rank.sort(['Average Rankings'], ascending=True)
subd_studio_rank.head(5)
# Out:
#                           Average Rankings
# Kyowa Film                              -1
# Orange                                  -1
# Automatic Flowers Studio                -1
# IMOVE                                   -1
# Buemon                                  -1

# %%
subd_studio_rank.ix[0:10,'Average Rankings']
# Out:
# Kyowa Film                   -1.0
# Orange                       -1.0
# Automatic Flowers Studio     -1.0
# IMOVE                        -1.0
# Buemon                       -1.0
# Pie in the sky               -1.0
# Pine Jam                     -1.0
# Shuka                       126.8
# IMAGIN                      171.0
# Studio Wombat               219.0
# Name: Average Rankings, dtype: float64

# %%
# PLOT TOP 10 STUDIOS BY FREQUENCY, AVERAGE RANKINGS, AND AVERAGE RATINGS FOR COMPARISONS

fig, axes= plt.subplots(nrows=1, ncols=3, figsize=(16,8))
x=np.arange(10)
axes[0].bar(x,subd_studio.ix[0:10,'Average Ratings'])
axes[0].set_title('Average Ratings')
axes[0].set_xticks(x)
axes[0].set_xticklabels(a.index.values[0:10], rotation=90)
axes[1].bar(x,subd.ix[0:10,'Frequency'])
axes[1].set_title('Frequency')
axes[1].set_xticks(x)
axes[1].set_xticklabels(a.index.values[0:10], rotation=90)
axes[2].bar(x,subd_studio_rank.ix[7:17,'Average Rankings']) # first 7 have -1 ranking, or no ranking
axes[2].set_title('Average Rankings')
axes[2].set_xticks(x)
axes[2].set_xticklabels(subd_studio_rank.index.values[7:17], rotation=90)
# Out:
# [<matplotlib.text.Text at 0x25235cf8>,
#  <matplotlib.text.Text at 0x25261518>,
#  <matplotlib.text.Text at 0x2549fd30>,
#  <matplotlib.text.Text at 0x23b0c400>,
#  <matplotlib.text.Text at 0x23b0ca90>,
#  <matplotlib.text.Text at 0x23b2e160>,
#  <matplotlib.text.Text at 0x23b2e7f0>,
#  <matplotlib.text.Text at 0x24826b00>,
#  <matplotlib.text.Text at 0x23b85470>,
#  <matplotlib.text.Text at 0x23b5fe48>]

# %%
data.head(5)
# Out:
#                                        altname                             atype                                         categories date  date_pub                                        description                                    name  rank                       rating                                            related         studio  votes  ratings  eps  emin  tlength            type
# (Making of) Evangelion: Another Impact     NaN  \n        Web (1 ep x 6 min)      [Sci Fi, CG Animation, Japan Animator's Exhibi...  NaN      2015  This episode is a making film of #12 "evangeli...  (Making of) Evangelion: Another Impact  5996    1.743 of 5 from 153 votes  [Neon Genesis Evangelion, Neon Genesis Evangel...   Studio Khara    153    1.743    1     6        6  \n        Web
# +A-Channel                                 NaN   \nDVD Special (11 eps x 2 min)           [Comedy, Slice of Life, Based on a Manga]  NaN      2011  There are many untold stories in the lives of ...                              +A-Channel  2398  3.334 of 5 from 1,192 votes                     [A-Channel, A-Channel + smile]  Studio Gokumi   1192    3.334   11     2       22  \nDVD Special
# .hack//G.U. Returner                       NaN                     \nOVA (1 ep)                      [MMORPG, RPG, Virtual Reality]  NaN      2007  "There is something I wish to entrust to you; ...                    .hack//G.U. Returner  2504  3.291 of 5 from 2,021 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN   2021    3.291    1     0        0          \nOVA
# .hack//G.U. Trilogy                        NaN          \nMovie (1 ep x 93 min)        [CG Animation, MMORPG, RPG, Virtual Reality]  NaN      2008  The World is an ordinary online game – or at l...                     .hack//G.U. Trilogy  1576  3.671 of 5 from 2,814 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN   2814    3.671    1    93       93        \nMovie
# .hack//G.U. Trilogy Parody                 NaN     \nDVD Special (1 ep x 6 min)              [Comedy, MMORPG, RPG, Virtual Reality]  NaN      2008                                                NaN              .hack//G.U. Trilogy Parody  3993    2.691 of 5 from 714 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN    714    2.691    1     6        6  \nDVD Special

# %%
# remove trailing spaces in type
for row in data.index:
    l=data.ix[row,"type"].strip(" ")
    l=l.replace(" ","")
    data.ix[row,"type"]=l
data.head(5)
# Out:
#                                        altname                             atype                                         categories date  date_pub                                        description                                    name  rank                       rating                                            related         studio  votes  ratings  eps  emin  tlength          type
# (Making of) Evangelion: Another Impact     NaN  \n        Web (1 ep x 6 min)      [Sci Fi, CG Animation, Japan Animator's Exhibi...  NaN      2015  This episode is a making film of #12 "evangeli...  (Making of) Evangelion: Another Impact  5996    1.743 of 5 from 153 votes  [Neon Genesis Evangelion, Neon Genesis Evangel...   Studio Khara    153    1.743    1     6        6         \nWeb
# +A-Channel                                 NaN   \nDVD Special (11 eps x 2 min)           [Comedy, Slice of Life, Based on a Manga]  NaN      2011  There are many untold stories in the lives of ...                              +A-Channel  2398  3.334 of 5 from 1,192 votes                     [A-Channel, A-Channel + smile]  Studio Gokumi   1192    3.334   11     2       22  \nDVDSpecial
# .hack//G.U. Returner                       NaN                     \nOVA (1 ep)                      [MMORPG, RPG, Virtual Reality]  NaN      2007  "There is something I wish to entrust to you; ...                    .hack//G.U. Returner  2504  3.291 of 5 from 2,021 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN   2021    3.291    1     0        0         \nOVA
# .hack//G.U. Trilogy                        NaN          \nMovie (1 ep x 93 min)        [CG Animation, MMORPG, RPG, Virtual Reality]  NaN      2008  The World is an ordinary online game – or at l...                     .hack//G.U. Trilogy  1576  3.671 of 5 from 2,814 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN   2814    3.671    1    93       93       \nMovie
# .hack//G.U. Trilogy Parody                 NaN     \nDVD Special (1 ep x 6 min)              [Comedy, MMORPG, RPG, Virtual Reality]  NaN      2008                                                NaN              .hack//G.U. Trilogy Parody  3993    2.691 of 5 from 714 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN    714    2.691    1     6        6  \nDVDSpecial

# %%
# Frequency of types
t=pd.value_counts(data['type'].values, sort=True)
subd_t=pd.DataFrame(t,t.index.values)
subd_t.columns=['Frequency']
subd_t.head(5)
# Out:
#               Frequency
# \nTV               2715
# \nOVA              1450
# \nMovie            1239
# \nDVDSpecial        528
# \nMusicVideo        328

# %%
# Type vs ratings
type_rating=data.groupby("type").aggregate(np.mean)["ratings"]
type_rating=type_rating.order(ascending=False)
subd_type_rating=pd.DataFrame(type_rating,type_rating.index.values)
subd_type_rating.columns=['Average Ratings']
subd_type_rating = subd_type_rating.sort(['Average Ratings'], ascending=False)
subd_type_rating.head(5)
# Out:
#               Average Ratings
# \nTV                 3.016259
# \nTVSpecial          2.940051
# \nDVDSpecial         2.914602
# \nMovie              2.836762
# \nOVA                2.763679

# %%
# Type vs rankings
type_rank=data.groupby("type").aggregate(np.mean)["rank"]
type_rank=type_rank.order(ascending=False)
subd_type_rank=pd.DataFrame(type_rank,type_rating.index.values)
subd_type_rank.columns=['Average Rankings']
subd_type_rank = subd_type_rank.sort(['Average Rankings'], ascending=True)
subd_type_rank.head(5)
# Out:
#               Average Rankings
# NA                   10.949367
# \nMovie            2745.891848
# \nTVSpecial        2779.708904
# \nTV               2786.073665
# \nDVDSpecial       3174.492424

# %%
# PLOT TOP 5 TYPES BY FREQUENCY, AVERAGE RANKINGS, AND AVERAGE RATINGS FOR COMPARISONS

fig, axes= plt.subplots(nrows=1, ncols=3, figsize=(16,8))
x=np.arange(5)
axes[0].bar(x,subd_type_rating.ix[0:5,'Average Ratings'])
axes[0].set_title('Average Ratings')
axes[0].set_xticks(x)
axes[0].set_xticklabels(t.index.values[0:5], rotation=90)
axes[1].bar(x,subd_t.ix[0:5,'Frequency'])
axes[1].set_title('Frequency')
axes[1].set_xticks(x)
axes[1].set_xticklabels(t.index.values[0:5], rotation=90)
axes[2].bar(x,subd_type_rank.ix[0:5,'Average Rankings'])
axes[2].set_title('Average Rankings')
axes[2].set_xticks(x)
axes[2].set_xticklabels(t.index.values[0:5], rotation=90)
# Out:
# [<matplotlib.text.Text at 0x20ed1630>,
#  <matplotlib.text.Text at 0x20eda7f0>,
#  <matplotlib.text.Text at 0x20ec4f98>,
#  <matplotlib.text.Text at 0x20eb7e10>,
#  <matplotlib.text.Text at 0x20d5afd0>]

# %%
# Tlength vs ratings
subd_length=pd.DataFrame(data["tlength"], data.index.values)
subd_length["ratings"]=data["ratings"]
subd_length
# Out:
#                                                     tlength  ratings
# (Making of) Evangelion: Another Impact                    6    1.743
# +A-Channel                                               22    3.334
# .hack//G.U. Returner                                      0    3.291
# .hack//G.U. Trilogy                                      93    3.671
# .hack//G.U. Trilogy Parody                                6    2.691
# .hack//GIFT                                               0    2.646
# .hack//LIMINALITY                                         0    3.064
# .hack//Legend Of The Twilight                             0    3.078
# .hack//Quantum                                            0    3.933
# .hack//Quantum Specials                                   9    2.916
# .hack//Roots                                            624    3.414
# .hack//SIGN                                               0    3.404
# .hack//SIGN - Intermezzo                                  0    3.236
# .hack//SIGN - Unison                                      0    3.281
# .hack//The Movie: Sekai no Mukou ni                     112    3.711
# .hack//Versus: The Thanatos Report                       21    2.846
# 009 Re:Cyborg                                             0    3.008
# 009-1                                                     0    2.265
# 009-1 Special                                            24    2.451
# 07-Ghost                                                  0    3.566
# 1+2=Paradise                                             60    1.623
# 1,2,3,4,                                                  7    1.031
# 10 Nights' Dreams                                         6    1.322
# 10 Tokyo Warriors                                       180    1.872
# 100 Byou Cinema: Robo to Shoujo (Kari)                   18    2.218
# 1001 Nights                                              24    2.395
# 11eyes                                                    0    2.811
# 11eyes Special                                           25    2.487
# 12-Sai.: Kiss, Kirai, Suki                               14    2.434
# 20min Walk From Nishi-Ogikubo Station, 2 Bedroo...       10    3.109
# ...                                                     ...      ...
# pair*                                                     5    1.806
# sasakure.UK: *Hello, Planet.                              5    1.836
# sasakure.UK: A Soliloquy of The Boy who Cried Wolf        5    1.550
# sasakure.UK: Butterfly Effect                             5    1.529
# sasakure.UK: For Campanella                               4    1.355
# sasakure.UK: Little Cry of The Abyss                      4    1.882
# sasakure.UK: Lost and Found                               5    1.610
# sasakure.UK: Mr. Wonderland                               5    1.572
# sasakure.UK: Non-World Harmonize                          4    1.249
# sasakure.UK: Patchwork Eden                               4    1.642
# sasakure.UK: Puppet Theater of Twee-Box                   4    1.577
# sasakure.UK: Spider Thread Monopoly                       5    1.463
# sasakure.UK: The Fantastic Diagram of Futuristi...        8    1.669
# sasakure.UK: The Fantastic Reality of Aesop               8    1.352
# sasakure.UK: The Trash-Heap Princess and Apostr...        5    1.884
# sasakure.UK: The UniversaL ElekiteL                       4    1.682
# sasakure.UK: Tiger Rampage                                5    1.830
# sasakure.UK: to Asteroid B-612                            5    1.271
# siinamota: MOSAIC                                         4    1.493
# siinamota: Pikkooon!!                                     4    1.393
# sola                                                      0    3.651
# sola Specials                                            48    3.173
# the pillows: 1989                                         7    1.913
# the pillows: Instant Music                                3    1.581
# the pillows: Wake Up! Dodo                                4    3.000
# until You come to me.                                     7    2.216
# wowaka: Antinotice                                        3    2.342
# xxxHOLiC Kei                                              0    4.400
# xxxHOLiC Rou                                             80    4.397
# xxxHOLiC Shunmuki                                         0    4.322
#
# [7281 rows x 2 columns]

# %%
subd_length.tlength.max()
# Out:
# 18080L

# %%
plt.scatter(subd_length["tlength"], subd_length["ratings"])
# Out:
# C:\Users\tle1925\Anaconda\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
# zoom in to data with lower tlength values
temp_subd=subd_length[subd_length["tlength"]<2000]
plt.scatter(temp_subd["tlength"], temp_subd["ratings"])

# %%
# zoom more into data with lower tlength values
temp_subd1=subd_length[subd_length["tlength"]<250]
plt.scatter(temp_subd1["tlength"], temp_subd1["ratings"])

# %%
# Tlength vs rankings
subd_length_rank=pd.DataFrame(data["tlength"], data.index.values)
subd_length_rank["rankings"]=data["rank"]
subd_length_rank
# Out:
#                                                     tlength  rankings
# (Making of) Evangelion: Another Impact                    6      5996
# +A-Channel                                               22      2398
# .hack//G.U. Returner                                      0      2504
# .hack//G.U. Trilogy                                      93      1576
# .hack//G.U. Trilogy Parody                                6      3993
# .hack//GIFT                                               0      4108
# .hack//LIMINALITY                                         0      3073
# .hack//Legend Of The Twilight                             0      3039
# .hack//Quantum                                            0       974
# .hack//Quantum Specials                                   9      3441
# .hack//Roots                                            624      2198
# .hack//SIGN                                               0      2224
# .hack//SIGN - Intermezzo                                  0      2639
# .hack//SIGN - Unison                                      0      2527
# .hack//The Movie: Sekai no Mukou ni                     112      1480
# .hack//Versus: The Thanatos Report                       21      3615
# 009 Re:Cyborg                                             0      3213
# 009-1                                                     0      5011
# 009-1 Special                                            24      4584
# 07-Ghost                                                  0      1828
# 1+2=Paradise                                             60      6187
# 1,2,3,4,                                                  7      6607
# 10 Nights' Dreams                                         6      6496
# 10 Tokyo Warriors                                       180      5778
# 100 Byou Cinema: Robo to Shoujo (Kari)                   18      5107
# 1001 Nights                                              24      4719
# 11eyes                                                    0      3703
# 11eyes Special                                           25      4498
# 12-Sai.: Kiss, Kirai, Suki                               14      4626
# 20min Walk From Nishi-Ogikubo Station, 2 Bedroo...       10      2962
# ...                                                     ...       ...
# pair*                                                     5      5893
# sasakure.UK: *Hello, Planet.                              5      5844
# sasakure.UK: A Soliloquy of The Boy who Cried Wolf        5      6274
# sasakure.UK: Butterfly Effect                             5      6301
# sasakure.UK: For Campanella                               4      6473
# sasakure.UK: Little Cry of The Abyss                      4      5758
# sasakure.UK: Lost and Found                               5      6203
# sasakure.UK: Mr. Wonderland                               5      6252
# sasakure.UK: Non-World Harmonize                          4      6541
# sasakure.UK: Patchwork Eden                               4      6161
# sasakure.UK: Puppet Theater of Twee-Box                   4      6244
# sasakure.UK: Spider Thread Monopoly                       5      6387
# sasakure.UK: The Fantastic Diagram of Futuristi...        8      6121
# sasakure.UK: The Fantastic Reality of Aesop               8      6475
# sasakure.UK: The Trash-Heap Princess and Apostr...        5      5754
# sasakure.UK: The UniversaL ElekiteL                       4      6097
# sasakure.UK: Tiger Rampage                                5      5854
# sasakure.UK: to Asteroid B-612                            5      6526
# siinamota: MOSAIC                                         4      6354
# siinamota: Pikkooon!!                                     4      6445
# sola                                                      0      1622
# sola Specials                                            48      2799
# the pillows: 1989                                         7      5709
# the pillows: Instant Music                                3      6241
# the pillows: Wake Up! Dodo                                4        -1
# until You come to me.                                     7      5112
# wowaka: Antinotice                                        3      4835
# xxxHOLiC Kei                                              0       154
# xxxHOLiC Rou                                             80       158
# xxxHOLiC Shunmuki                                         0       270
#
# [7281 rows x 2 columns]

# %%
plt.scatter(subd_length_rank["tlength"], subd_length_rank["rankings"])

# %%
# zoom more into data with lower tlength values
temp_subdl=subd_length_rank[subd_length_rank["tlength"]<100]
plt.scatter(temp_subdl["tlength"], temp_subdl["rankings"])

# %%
# episodes vs rankings
subd_ep_rank=pd.DataFrame(data["eps"], data.index.values)
subd_ep_rank["rankings"]=data["rank"]
subd_ep_rank.head(5)
# Out:
#                                         eps  rankings
# (Making of) Evangelion: Another Impact    1      5996
# +A-Channel                               11      2398
# .hack//G.U. Returner                      1      2504
# .hack//G.U. Trilogy                       1      1576
# .hack//G.U. Trilogy Parody                1      3993

# %%
plt.scatter(subd_ep_rank['eps'],subd_ep_rank['rankings'])

# %%
temp_subdep=subd_ep_rank[subd_ep_rank['eps']<100]
plt.scatter(temp_subdep['eps'], temp_subdep['rankings'])

# %%
# episodes vs ratings
subd_ep_rating=pd.DataFrame(data["eps"], data.index.values)
subd_ep_rating["ratings"]=data["ratings"]
subd_ep_rating.head(5)
# Out:
#                                         eps  ratings
# (Making of) Evangelion: Another Impact    1    1.743
# +A-Channel                               11    3.334
# .hack//G.U. Returner                      1    3.291
# .hack//G.U. Trilogy                       1    3.671
# .hack//G.U. Trilogy Parody                1    2.691

# %%
plt.scatter(subd_ep_rating['eps'],subd_ep_rating['ratings'])

# %%
temp_subdep1=subd_ep_rating[subd_ep_rating['eps']<100]
plt.scatter(temp_subdep1['eps'], temp_subdep1['ratings'])

# %%
# Votes vs ratings
subd_v_rating=pd.DataFrame(data["votes"], data.index.values)
subd_v_rating["ratings"]=data["ratings"]
subd_v_rating.head(5)
# Out:
#                                         votes  ratings
# (Making of) Evangelion: Another Impact    153    1.743
# +A-Channel                               1192    3.334
# .hack//G.U. Returner                     2021    3.291
# .hack//G.U. Trilogy                      2814    3.671
# .hack//G.U. Trilogy Parody                714    2.691

# %%
plt.scatter(subd_v_rating["votes"], subd_v_rating["ratings"])

# %%
# Votes s rankings
subd_v_rank=pd.DataFrame(data["votes"], data.index.values)
subd_v_rank["rankings"]=data["rank"]
subd_v_rank.head(5)
# Out:
#                                         votes  rankings
# (Making of) Evangelion: Another Impact    153      5996
# +A-Channel                               1192      2398
# .hack//G.U. Returner                     2021      2504
# .hack//G.U. Trilogy                      2814      1576
# .hack//G.U. Trilogy Parody                714      3993

# %%
plt.scatter(subd_v_rank["votes"], subd_v_rank["rankings"])

# %%
# Date_pub vs ratings and rankings
subd_dp=pd.DataFrame(data["date_pub"], data.index.values)
subd_dp["rankings"]=data["rank"]
subd_dp["ratings"]=data["ratings"]
subd_dp.head(5)
# Out:
#                                         date_pub  rankings  ratings
# (Making of) Evangelion: Another Impact      2015      5996    1.743
# +A-Channel                                  2011      2398    3.334
# .hack//G.U. Returner                        2007      2504    3.291
# .hack//G.U. Trilogy                         2008      1576    3.671
# .hack//G.U. Trilogy Parody                  2008      3993    2.691

# %%
# date_pub vs rankings
plt.scatter(subd_dp["date_pub"], subd_dp["rankings"])

# %% [markdown]
# We can see significant movement of rankings every ~10 year interval, hence we assume that there's a slight improvement in
# rankings after each decade

# %%
plt.scatter(subd_dp["date_pub"], subd_dp["ratings"])

# %%
data.head(5)
# Out:
#                                        altname                             atype                                         categories date  date_pub                                        description                                    name  rank                       rating                                            related         studio  votes  ratings  eps  emin  tlength          type
# (Making of) Evangelion: Another Impact     NaN  \n        Web (1 ep x 6 min)      [Sci Fi, CG Animation, Japan Animator's Exhibi...  NaN      2015  This episode is a making film of #12 "evangeli...  (Making of) Evangelion: Another Impact  5996    1.743 of 5 from 153 votes  [Neon Genesis Evangelion, Neon Genesis Evangel...   Studio Khara    153    1.743    1     6        6         \nWeb
# +A-Channel                                 NaN   \nDVD Special (11 eps x 2 min)           [Comedy, Slice of Life, Based on a Manga]  NaN      2011  There are many untold stories in the lives of ...                              +A-Channel  2398  3.334 of 5 from 1,192 votes                     [A-Channel, A-Channel + smile]  Studio Gokumi   1192    3.334   11     2       22  \nDVDSpecial
# .hack//G.U. Returner                       NaN                     \nOVA (1 ep)                      [MMORPG, RPG, Virtual Reality]  NaN      2007  "There is something I wish to entrust to you; ...                    .hack//G.U. Returner  2504  3.291 of 5 from 2,021 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN   2021    3.291    1     0        0         \nOVA
# .hack//G.U. Trilogy                        NaN          \nMovie (1 ep x 93 min)        [CG Animation, MMORPG, RPG, Virtual Reality]  NaN      2008  The World is an ordinary online game – or at l...                     .hack//G.U. Trilogy  1576  3.671 of 5 from 2,814 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN   2814    3.671    1    93       93       \nMovie
# .hack//G.U. Trilogy Parody                 NaN     \nDVD Special (1 ep x 6 min)              [Comedy, MMORPG, RPG, Virtual Reality]  NaN      2008                                                NaN              .hack//G.U. Trilogy Parody  3993    2.691 of 5 from 714 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN    714    2.691    1     6        6  \nDVDSpecial

# %%
# get categories list
cats=[]
for row in data.index:
    l=data.ix[row,"categories"]
    if type(l)==float:
        l="NA"
    else:
        l=l.replace("[","").replace("]","")
        n=l.split(",")
        for word in n:
            word=word.strip(" ")
            cats.append(word)

# %%
c=pd.value_counts(cats, sort=True)
subd_cat=pd.DataFrame(c, c.index.values)
subd_cat.columns=['Frequency']
subd_cat=subd_cat.sort()
subd_cat.head(5)
# Out:
#                     Frequency
# Abstract                   65
# Action                   1428
# Adventure                 591
# Age Gap                     8
# Age Transformation          7

# %%
# PLOT TOP 10 CATEGORIES BY FREQUENCY
subd_cat_freq=subd_cat.sort(["Frequency"], ascending=False)
x=np.arange(10)
plt.bar(x,subd_cat_freq.ix[0:10,'Frequency'])
plt.xticks(x, c.index.values[0:10], rotation='vertical')
plt.show()

# %%
# categories vs ratings
from collections import defaultdict
cat_rat=defaultdict(int)
for row in data.index:
    l=data.ix[row,"categories"]
    if type(l)==float:
        l="NA"
    else:
        l=l.replace("[","").replace("]","")
        n=l.split(",")
        for word in n:
            word=word.strip(" ")
            cat_rat[word]+=data.ix[row,"ratings"]

# %%
subd_cat_rating=pd.DataFrame([cat_rat]).T
subd_cat_rating.columns=['Total Ratings']
subd_cat_rating = subd_cat_rating.sort()
subd_cat_rating["Frequency"]=subd_cat["Frequency"]
subd_cat_rating["Average Ratings"]=subd_cat_rating["Total Ratings"]/subd_cat["Frequency"]
subd_cat_rating = subd_cat_rating.sort(['Average Ratings'], ascending=False)
subd_cat_rating.head(5)
# Out:
#                     Total Ratings  Frequency  Average Ratings
# Yaoi Hand Syndrome         33.189          8         4.148625
# Youkai                      4.055          1         4.055000
# Age Gap                    31.725          8         3.965625
# Terrorism                  43.020         11         3.910909
# Coming of Age             183.670         47         3.907872

# %%
from collections import defaultdict
cat_rank=defaultdict(int)
for row in data.index:
    l=data.ix[row,"categories"]
    if type(l)==float:
        l="NA"
    else:
        l=l.replace("[","").replace("]","")
        n=l.split(",")
        for word in n:
            word=word.strip(" ")
            cat_rank[word]+=data.ix[row,"rank"]

# %%
subd_cat_rank=pd.DataFrame([cat_rank]).T
subd_cat_rank.columns=['Total Rankings']
subd_cat_rank= subd_cat_rank.sort()
subd_cat_rank["Frequency"]=subd_cat["Frequency"]
subd_cat_rank["Average Rankings"]=subd_cat_rank["Total Rankings"]/subd_cat["Frequency"]
subd_cat_rank= subd_cat_rank.sort(['Average Rankings'], ascending=True)
subd_cat_rank.head(5)
# Out:
#                     Total Rankings  Frequency  Average Rankings
# Yaoi Hand Syndrome            5392          8        674.000000
# Youkai                         731          1        731.000000
# Age Gap                       8299          8       1037.375000
# Thriller                     27355         26       1052.115385
# noitaminA                    70673         67       1054.820896

# %%
fig, axes= plt.subplots(nrows=1, ncols=2, figsize=(16,8))
x=np.arange(10)
axes[0].bar(x,subd_cat_rating.ix[0:10,'Average Ratings'])
axes[0].set_title('Average Ratings')
axes[0].set_xticks(x)
axes[0].set_xticklabels(subd_cat_rating.index.values[0:10], rotation=90)
axes[1].bar(x,subd_cat_rank.ix[0:10,'Average Rankings'])
axes[1].set_title('Average Rankings')
axes[1].set_xticks(x)
axes[1].set_xticklabels(subd_cat_rank.index.values[0:10], rotation=90)
# Out:
# [<matplotlib.text.Text at 0x249aaba8>,
#  <matplotlib.text.Text at 0x24a100f0>,
#  <matplotlib.text.Text at 0x24aeef98>,
#  <matplotlib.text.Text at 0x24b42668>,
#  <matplotlib.text.Text at 0x24b42cf8>,
#  <matplotlib.text.Text at 0x24b4c3c8>,
#  <matplotlib.text.Text at 0x24b4ca58>,
#  <matplotlib.text.Text at 0x24b57128>,
#  <matplotlib.text.Text at 0x24b577b8>,
#  <matplotlib.text.Text at 0x24b57e48>]

# %%
data.head(5)
# Out:
#                                        altname                             atype                                         categories date  date_pub                                        description                                    name  rank                       rating                                            related         studio  votes  ratings  eps  emin  tlength          type
# (Making of) Evangelion: Another Impact     NaN  \n        Web (1 ep x 6 min)      [Sci Fi, CG Animation, Japan Animator's Exhibi...  NaN      2015  This episode is a making film of #12 "evangeli...  (Making of) Evangelion: Another Impact  5996    1.743 of 5 from 153 votes  [Neon Genesis Evangelion, Neon Genesis Evangel...   Studio Khara    153    1.743    1     6        6         \nWeb
# +A-Channel                                 NaN   \nDVD Special (11 eps x 2 min)           [Comedy, Slice of Life, Based on a Manga]  NaN      2011  There are many untold stories in the lives of ...                              +A-Channel  2398  3.334 of 5 from 1,192 votes                     [A-Channel, A-Channel + smile]  Studio Gokumi   1192    3.334   11     2       22  \nDVDSpecial
# .hack//G.U. Returner                       NaN                     \nOVA (1 ep)                      [MMORPG, RPG, Virtual Reality]  NaN      2007  "There is something I wish to entrust to you; ...                    .hack//G.U. Returner  2504  3.291 of 5 from 2,021 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN   2021    3.291    1     0        0         \nOVA
# .hack//G.U. Trilogy                        NaN          \nMovie (1 ep x 93 min)        [CG Animation, MMORPG, RPG, Virtual Reality]  NaN      2008  The World is an ordinary online game – or at l...                     .hack//G.U. Trilogy  1576  3.671 of 5 from 2,814 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN   2814    3.671    1    93       93       \nMovie
# .hack//G.U. Trilogy Parody                 NaN     \nDVD Special (1 ep x 6 min)              [Comedy, MMORPG, RPG, Virtual Reality]  NaN      2008                                                NaN              .hack//G.U. Trilogy Parody  3993    2.691 of 5 from 714 votes  [.hack//SIGN, .hack//LIMINALITY, .hack//Legend...            NaN    714    2.691    1     6        6  \nDVDSpecial

# %%
# Create dataframe with all possible predictors
df=pd.DataFrame(data["rank"], data.index.values)
df["rate"]=data["ratings"]
df["tlength"]= data["tlength"]
df["type"]=data["type"]
df["votes"]=data["votes"]
df["studio"]=data["studio"]
df["date_pub"]=data["date_pub"]
df["categories"]=data["categories"]
df.head(5)
# Out:
#                                         rank   rate  tlength          type  votes         studio  date_pub                                         categories
# (Making of) Evangelion: Another Impact  5996  1.743        6         \nWeb    153   Studio Khara      2015  [Sci Fi, CG Animation, Japan Animator's Exhibi...
# +A-Channel                              2398  3.334       22  \nDVDSpecial   1192  Studio Gokumi      2011          [Comedy, Slice of Life, Based on a Manga]
# .hack//G.U. Returner                    2504  3.291        0         \nOVA   2021            NaN      2007                     [MMORPG, RPG, Virtual Reality]
# .hack//G.U. Trilogy                     1576  3.671       93       \nMovie   2814            NaN      2008       [CG Animation, MMORPG, RPG, Virtual Reality]
# .hack//G.U. Trilogy Parody              3993  2.691        6  \nDVDSpecial    714            NaN      2008             [Comedy, MMORPG, RPG, Virtual Reality]

# %%
df[1:10]
# Out:
#                                rank   rate  tlength          type  votes         studio  date_pub                                    categories
# +A-Channel                     2398  3.334       22  \nDVDSpecial   1192  Studio Gokumi      2011     [Comedy, Slice of Life, Based on a Manga]
# .hack//G.U. Returner           2504  3.291        0         \nOVA   2021            NaN      2007                [MMORPG, RPG, Virtual Reality]
# .hack//G.U. Trilogy            1576  3.671       93       \nMovie   2814            NaN      2008  [CG Animation, MMORPG, RPG, Virtual Reality]
# .hack//G.U. Trilogy Parody     3993  2.691        6  \nDVDSpecial    714            NaN      2008        [Comedy, MMORPG, RPG, Virtual Reality]
# .hack//GIFT                    4108  2.646        0         \nOVA   2721      BEE TRAIN      2003         [Chibi, MMORPG, RPG, Virtual Reality]
# .hack//LIMINALITY              3073  3.064        0         \nOVA   4253      BEE TRAIN      2002                                           NaN
# .hack//Legend Of The Twilight  3039  3.078        0          \nTV   7252      BEE TRAIN      2003        [Sci Fi, MMORPG, RPG, Virtual Reality]
# .hack//Quantum                  974  3.933        0         \nOVA   2328  Kinema Citrus      2010             [Action, Mystery, Sci Fi, MMORPG]
# .hack//Quantum Specials        3441  2.916        9  \nDVDSpecial    311  Kinema Citrus      2011                                           NaN

# %%
df.shape
# Out:
# (7281, 8)

# %%
df = df[df.rate>0]
df = df[df.tlength>0]
df.shape
# Out:
# (3484, 8)

# %%
df[200:300]
# Out:
#                                                     rank   rate  tlength          type  votes                     studio  date_pub                                         categories
# Ariel Deluxe                                        5500  2.027       90         \nOVA     35                    ANIMATE      1991             [Comedy, Mecha, Sci Fi, Original Work]
# Arion                                               4845  2.338      120       \nMovie    259                    Sunrise      1986                        [Fantasy, Based on a Manga]
# Ark IX                                              5986  1.748       11         \nOVA    151        Hoods Entertainment      2013         [Based on a Light Novel, Post-apocalyptic]
# Armitage III Dual-Matrix                            2207  3.411       90       \nMovie   2884                        AIC      2002  [Action, Sci Fi, Androids, Cyberpunk, Original...
# Armitage III Poly-Matrix                            2038  3.481       95       \nMovie   2680                        AIC      1997  [Action, Sci Fi, Androids, Cyberpunk, Original...
# Armored Trooper Votoms Case;Irvine                  3002  3.092       50         \nOVA    179                    Sunrise      2010                                    [Original Work]
# Armored Trooper Votoms: Alone Again                 2318  3.367       50         \nOVA    144                    Sunrise      2011                                    [Original Work]
# Armored Trooper Votoms: Big Battle                  3365  2.946       60         \nOVA    202                    Sunrise      1986             [Action, Mecha, Sci Fi, Original Work]
# Armored Trooper Votoms: Pailsen Files Movie         2257  3.390      118       \nMovie    112          The Answer Studio      2009                                    [Original Work]
# Armored Trooper Votoms: Phantom Arc                 2758  3.189      150         \nOVA    152                    Sunrise      2010                                    [Original Work]
# Armored Trooper Votoms: Red Shoulder Document -...  2486  3.298       60         \nOVA    273                    Sunrise      1988   [Action, Mecha, Sci Fi, Military, Original Work]
# Around                                              5663  1.941        3       \nMovie     36        Ryu Kato Film Works      2007                            [Original Work, Shorts]
# Arslan Senki Specials                               2483  3.299        4  \nDVDSpecial     49  SANZIGEN Animation Studio      2015                                           [Comedy]
# Art of Fighting                                     6212  1.603       50   \nTVSpecial    217               Studio Comet      1993      [Action, Based on a Video Game, Martial Arts]
# Arve Rezzle: Kikaijikake no Yousei-tachi            3663  2.827       24       \nMovie    896                      Zexcs      2013  [Action, Sci Fi, Anime Mirai, Based on a Light...
# Beluga                                                -1  2.000        6       \nMovie      0                        NaN      2011                                   [Horror, Shorts]
# Benkei Tai Ushiwaka                                 6117  1.671       14       \nMovie     18                        NaN      1939                          [Black and White, Shorts]
# Berserk Golden Age Arc I: Egg of the Supreme Ruler   285  4.312       80       \nMovie   4487                 Studio 4°C      2012  [Action, Fantasy, Based on a Manga, Demons, Me...
# Berserk Golden Age Arc III: Descent                  107  4.441      113       \nMovie   3220                 Studio 4°C      2013  [Action, Fantasy, Based on a Manga, Demons, Ex...
# Beyblade - The Movie                                4806  2.356       70       \nMovie   1763             Nihon-Animedia      2002                                  [Action, Shounen]
# Beyond the Boundary Episode 0: Shinonome             609  4.118       24  \nDVDSpecial   1361            Kyoto Animation      2014                           [Action, Fantasy, Magic]
# Beyond the Boundary: Idol Saiban! Mayoi Nagara ...  3906  2.727       35         \nWeb    957            Kyoto Animation      2013                                           [Comedy]
# Beyond the Boundary: Mini Theater                   5091  2.226       42  \nDVDSpecial    324            Kyoto Animation      2014                                                NaN
# Beyond the Boundary: Yakusoku no Kizuna             3817  2.763        4  \nDVDSpecial     85            Kyoto Animation      2015                                                NaN
# Beyond the Train Tracks                             4366  2.541       15       \nMovie     26                        NaN      2006                                                NaN
# Big Wars                                            5472  2.044       70       \nMovie    341                  Magic Bus      1993  [Sci Fi, Military, Outer Space, Psychic Powers...
# Bihada Ichizoku                                     5569  1.989      120          \nTV    125                        NaN      2008  [Drama, Romance, Shoujo, Fashion, Original Wor...
# Bikini Warriors                                     6426  1.410       48          \nTV    901                       Feel      2015              [Comedy, Ecchi, Fantasy, Parody, RPG]
# Binchou-tan                                         3338  2.956      144          \nTV    569                Studio Deen      2006  [Comedy, Slice of Life, Based on a Manga, Chib...
# Binchou-tan Movie                                   5118  2.212        4         \nOVA    234               Ishikawa Pro      2005  [Slice of Life, Chibi, Countryside, Family Fri...
# Bio Hunter                                          5076  2.234       60         \nOVA   1070                   MADHOUSE      1995        [Action, Horror, Demons, Explicit Violence]
# Birth                                               5809  1.856       80         \nOVA    189         Kaname Productions      1984                [Action, Adventure, Comedy, Sci Fi]
# Bishoujo Mobage: Mobami-chan                        5740  1.893        2       \nOther     48             Studio Trigger      2014                                      [Promotional]
# Bishoujo Senshi Sailor Moon Sailor Stars Hero Club  2421  3.324       90         \nOVA    487             Toei Animation      1996                      [Magical Girl, Shoujo, Magic]
# Bite Me! Chameleon                                  4660  2.421       50         \nOVA    127                        NaN      1996           [Ecchi, Crude, Delinquents, School Life]
#
# [100 rows x 8 columns]

# %%
for row in df.index:
    c=data.ix[row,"categories"]
    if type(c)==float:
        df.drop(row, inplace=True)
    else:
        s=data.ix[row,"studio"]
        if type(s)==float:
            df.drop(row, inplace=True)

# %%
df.shape
df.head(1)
# Out:
#                                         rank   rate  tlength   type  votes        studio  date_pub                                         categories
# (Making of) Evangelion: Another Impact  5996  1.743        6  \nWeb    153  Studio Khara      2015  [Sci Fi, CG Animation, Japan Animator's Exhibi...

# %%
# fit functions without categories (categories include several different categories and hence would complicate estimations)
import statsmodels.api as sm
from statsmodels.formula.api import glm, ols
ols_model = ols('rank ~ tlength + type + votes + date_pub', df).fit()
ols_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rank   R-squared:                       0.252
# Model:                            OLS   Adj. R-squared:                  0.248
# Method:                 Least Squares   F-statistic:                     72.91
# Date:                Sun, 06 Dec 2015   Prob (F-statistic):          7.54e-129
# Time:                        15:36:12   Log-Likelihood:                -19259.
# No. Observations:                2180   AIC:                         3.854e+04
# Df Residuals:                    2169   BIC:                         3.860e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------
# Intercept            8.568e+04   7512.449     11.405      0.000       7.1e+04     1e+05
# type[T.
# Movie]       -611.8918    125.345     -4.882      0.000      -857.700  -366.083
# type[T.
# MusicVideo]   798.5846    314.962      2.535      0.011       180.925  1416.244
# type[T.
# OVA]          243.8822    128.030      1.905      0.057        -7.193   494.957
# type[T.
# Other]        244.6929    201.762      1.213      0.225      -150.973   640.359
# type[T.
# TV]          1231.9289    145.884      8.445      0.000       945.842  1518.016
# type[T.
# TVSpecial]   -285.7209    157.384     -1.815      0.070      -594.360    22.919
# type[T.
# Web]         1421.2097    164.998      8.613      0.000      1097.638  1744.781
# tlength                -0.4397      0.083     -5.325      0.000        -0.602    -0.278
# votes                  -0.1560      0.011    -14.739      0.000        -0.177    -0.135
# date_pub              -41.0574      3.738    -10.982      0.000       -48.389   -33.726
# ==============================================================================
# Omnibus:                       94.595   Durbin-Watson:                   1.608
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.340
# Skew:                          -0.038   Prob(JB):                     1.74e-09
# Kurtosis:                       2.338   Cond. No.                     8.45e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.45e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Very low R^2 value, pretty bad model, but somewhat reasonable in realistically 
# Try dropping type
ols_model1 = ols('rank ~ tlength + votes + date_pub', df).fit()
ols_model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   rank   R-squared:                       0.149
# Model:                            OLS   Adj. R-squared:                  0.148
# Method:                 Least Squares   F-statistic:                     127.4
# Date:                Sun, 06 Dec 2015   Prob (F-statistic):           5.05e-76
# Time:                        16:40:14   Log-Likelihood:                -19398.
# No. Observations:                2180   AIC:                         3.880e+04
# Df Residuals:                    2176   BIC:                         3.883e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   4.123e+04   6996.939      5.892      0.000      2.75e+04  5.49e+04
# tlength       -0.2710      0.086     -3.148      0.002        -0.440    -0.102
# votes         -0.1994      0.011    -18.504      0.000        -0.221    -0.178
# date_pub     -18.7941      3.492     -5.382      0.000       -25.642   -11.946
# ==============================================================================
# Omnibus:                      434.905   Durbin-Watson:                   1.577
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.166
# Skew:                           0.007   Prob(JB):                     1.18e-19
# Kurtosis:                       2.020   Cond. No.                     7.39e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.39e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df.date_pub.min()
# Out:
# 1933.0

# %%
years=[
    (1930,1940),
    (1940,1950),
    (1950,1960),
    (1960,1970),
    (1970,1980),
    (1980,1990),
    (1990,2000),
    (2000,2010),
    (2010,2020)]

# %%
dict_y=dict()
for year in years:
    temp_df=df[(df.date_pub>=year[0]) & (df.date_pub<=year[1])]
    dict_y[year]=temp_df

# %%
dict_y[(1990,2000)]
# Out:
#                                                rank   rate  tlength          type  votes              studio  date_pub                                         categories
# 1+2=Paradise                                   6187  1.623       60         \nOVA    571           J.C.Staff      1990  [Comedy, Ecchi, Based on a Manga, Gynophobia, ...
# 1001 Nights                                    4719  2.395       24       \nMovie    662           Mushi Pro      1998        [Fantasy, Romance, Abstract, Original Work]
# Azuki-chan Movie                               4382  2.534       30       \nMovie     25            MADHOUSE      1995                                    [Original Work]
# Bakumatsu no Spasibo                           3022  3.084       85       \nMovie     12           Magic Bus      1997                                       [Historical]
# Bavel no Hon                                   5440  2.060        5   \nTVSpecial    296  Yamamura Animation      1996                       [Adventure, Fantasy, Shorts]
# Be-Bop High School                             4249  2.588      350         \nOVA     33      Toei Animation      1990  [Comedy, Based on a Manga, Delinquents, School...
# ...                                             ...    ...      ...           ...    ...                 ...       ...                                                ...
# The Boy Who Saw The Wind                       2938  3.119       95       \nMovie    452         Brains-Base      2000                     [Adventure, Fantasy, Military]
# The Hard: Bounty Hunter                        5296  2.130       55         \nOVA     32           J.C.Staff      1996                                   [Bounty Hunters]
# The Laws of the Sun                            5573  1.987      104       \nMovie     13           Group TAC      2000                                         [Religion]
# The Legend Of The Dog Warriors: The Hakkenden  4464  2.499      180         \nOVA    494                 AIC      1990     [Action, Feudal Japan, Supernatural, Violence]
# Tobira o Akete (1995)                          3954  2.708       11         \nOVA    324          Studio 4°C      1995                                 [Abstract, Shorts]
# Tokimeki Memorial                              4022  2.680      100         \nOVA    221      Studio Pierrot      1999    [Romance, Based on a Visual Novel, School Life]
# Tokyo Revelation                               4599  2.445       55       \nMovie    401           J.C.Staff      1995                   [Action, Horror, Demons, Nudity]
# Transformers: Zone                             4907  2.311       23         \nOVA    142      Toei Animation      1990                                    [Mecha, Sci Fi]
# Twilight of the Dark Master                    5288  2.133       50       \nMovie    704      Toei Animation      1998                [Horror, Demons, Explicit Violence]
# Ushiro no Shoumen Dare                         1893  3.539       92       \nMovie     82           Mushi Pro      1991                               [Drama, World War 2]
# Vampire Hunter D: Bloodlust                     551  4.150      102       \nMovie  11337            MADHOUSE      2000  [Action, Based on a Novel, Mercenaries, Post-a...
# Vampire Wars                                   6245  1.577       50         \nOVA    492      Toei Animation      1990                           [Supernatural, Vampires]
# Vampiyan Kids Pilot                            5225  2.162       18       \nOther     30      Production I.G      1999                                         [Vampires]
# Very Private Lesson                            5433  2.063       80         \nOVA    358                 AIC      1998                             [Ecchi, Mature Themes]
# Violence Jack 3: Hell's Wind                   5712  1.910       55         \nOVA    354    Dynamic Planning      1990  [Action, Horror, Based on a Manga, Explicit Vi...
# Violinist of Hamelin Movie                     4379  2.535       30       \nMovie    115    Nippon Animation      1996                                  [Comedy, Fantasy]
# Virgin Fleet                                   6155  1.646       90         \nOVA    175                 AIC      1998  [Fantasy, Aviation, Military, School Life, Sup...
# Whisper of the Heart                            232  4.346      111       \nMovie   9456       Studio Ghibli      1995  [Comedy, Drama, Romance, Slice of Life, Based ...
# Wizardry                                       4916  2.306       50         \nOVA    169   TMS Entertainment      1991                                          [Fantasy]
# X: The Movie                                   3549  2.872      100       \nMovie   5267            MADHOUSE      1996  [Action, Shoujo, Based on a Manga, Explicit Vi...
# Yagami-kun's Family Affairs                    4186  2.615       90         \nOVA     33      Production I.G      1990                [Comedy, Romance, Based on a Manga]
# Yamato 2520                                    5059  2.242      180         \nOVA     40     Studio Take Off      1995     [Action, Adventure, Sci Fi, Based on an Anime]
# Yawara! Sore Yuke Koshinuke Kiss!!             3431  2.921       60       \nMovie     48            MADHOUSE      1992                                     [Martial Arts]
# Yawara! Special: Zutto Kimi no Koto ga         1241  3.814       92   \nTVSpecial     55            MADHOUSE      1996                                           [Sports]
# Yoiko                                          5309  2.124      240          \nTV    156      Studio Pierrot      1998                       [Ecchi, Nudity, School Life]
# You're Under Arrest! The Movie                 1347  3.768       90       \nMovie    807         Studio Deen      1999                                   [Action, Police]
# Your Choice!                                   5860  1.826       10       \nMovie     25  Yamamura Animation      1999                      [Animal Protagonists, Shorts]
# Yu-Gi-Oh! Movie 1                              3832  2.757       30       \nMovie   3536      Toei Animation      1999                                     [Card Battles]
# Zetsuai 1989                                   4055  2.667       50       \nMovie   1033            MADHOUSE      1992  [Drama, Romance, Shounen-ai, Idols, LGBT Theme...
# Zetsuai Bronze 1989                            4164  2.624       48         \nOVA   1074      Production I.G      1996  [Drama, Romance, Shounen-ai, LGBT Themes, Sexu...
#
# [343 rows x 8 columns]

# %%
dict_f=dict()
r2=[]
nrow=[]
for year in years:
    if (dict_y[year].shape[0]>1):
        temp_df=dict_y[year]
        ols_model2 = ols('rank ~ tlength + type + votes + date_pub', temp_df).fit()
        dict_f[year]=ols_model2
        r2.append(ols_model2.rsquared)
        nrow.append(dict_y[year].shape[0])

# %%
subd_fit=pd.DataFrame(r2,dict_f.keys())
subd_fit.columns=["R-squared"]
subd_fit['nrow']=nrow
subd_fit=subd_fit.sort()
subd_fit
# Out:
#               R-squared  nrow
# (1950, 1960)   0.135526    21
# (1960, 1970)   0.733119     5
# (1970, 1980)   0.368842   849
# (1980, 1990)   0.228781   862
# (1990, 2000)   0.287251    61
# (2000, 2010)   0.271390   343
# (2010, 2020)   0.310188   240

# %% [markdown]
# No significant improvement, higher R-squared is due to smaller number of data -> less variation

# %% [markdown]
# 7281 data points
# *Tlength = number of episodes x minutes/episode
#
# Studios:
# -	Strong correlation between frequency and average ratings: higher frequency (number of studios that anime come from, higher the ratings) -> can also indicate bias that studios produce better movies are more popular, produce more popular animes, and hence have more ratings since the animes are more well-known
# -	Much greater variation in frequency compared to differences among average ratings among animes
# -	No correlation between ratings and rankings. The top 10 rankings don’t overlap with top 10 ratings generally
#
# Types:
# -	Same as studios but there’s strong correlation between average ratings and rankings. The lists are exactly the same in the same order.
#
# Tlengths:
# -	Most movies tends to have length of less than 100 minutes in total- cluster toward lower lengths, with some outliers
# -	No systematic correlation between tlengths and ratings/rankings
#
# Episodes:
# -	Most movies have under 50 episodes, with lots of clusters around 1 episode, 15-20 episodes, 20-25 episodes, and 50-55 episodes
# -	No systematic correlation with ratings and rankings
#
# Votes:
# -	More votes -> higher ratings -> lower ranks (higher place)
# -	Votes and ratings/rankings are curve graphs
#
# Date_pub:
# -	Small clusters around 1930s -> lots of animes in this period have very high ranks (bad ranking)
# -	But closer to the recent dates tend to generally have a bit better rankings (low ranks) but pretty random
#
# Categories:
# -	Some overlapping between ratings and rankings (esp for top ratings ones and top ranks) but less later in top 10
# -	Frequency doesn’t correlate with ratings and rankings at all – VERY DIFFERENT LISTS
